# %% [markdown]
# # SSD Evaluation
# Model's evaluation using method described [here](http://host.robots.ox.ac.uk/pascal/VOC/voc2012/htmldoc/devkit_doc.html#sec:ap).

# %%
from keras import backend as K
from keras.models import load_model
from keras.optimizers import Adam
from scipy.misc import imread
import numpy as np
from matplotlib import pyplot as plt

from models.keras_ssd300 import ssd_300
from keras_loss_function.keras_ssd_loss import SSDLoss
from keras_layers.keras_layer_AnchorBoxes import AnchorBoxes
from keras_layers.keras_layer_DecodeDetections import DecodeDetections
from keras_layers.keras_layer_DecodeDetectionsFast import DecodeDetectionsFast
from keras_layers.keras_layer_L2Normalization import L2Normalization
from data_generator.object_detection_2d_data_generator import DataGenerator
from eval_utils.average_precision_evaluator import Evaluator

# %matplotlib inline
# Out:
# Using TensorFlow backend.
# /jet/prs/workspace/ssd_keras/data_generator/object_detection_2d_data_generator.py:43: UserWarning: 'BeautifulSoup' module is missing. The XML-parser will be unavailable.
#   warnings.warn("'BeautifulSoup' module is missing. The XML-parser will be unavailable.")

# %%
# Set a few configuration parameters.
img_height = 300
img_width = 420
n_classes = 42
model_mode = 'inference'

# %% [markdown]
# ## 1. Load a trained SSD

# %% [markdown]
# ### 1.1. Build the model and load trained weights into it

# %%
# 1: Build the Keras model

K.clear_session() # Clear previous models from memory.

model = ssd_300(image_size=(img_height, img_width, 3),
                n_classes=n_classes,
                mode=model_mode,
                l2_regularization=0.0005,
                scales=[0.1, 0.2, 0.37, 0.54, 0.71, 0.88, 1.05], # The scales for MS COCO [0.07, 0.15, 0.33, 0.51, 0.69, 0.87, 1.05]
                aspect_ratios_per_layer=[[1.0, 2.0, 0.5],
                                         [1.0, 2.0, 0.5, 3.0, 1.0/3.0],
                                         [1.0, 2.0, 0.5, 3.0, 1.0/3.0],
                                         [1.0, 2.0, 0.5, 3.0, 1.0/3.0],
                                         [1.0, 2.0, 0.5],
                                         [1.0, 2.0, 0.5]],
                two_boxes_for_ar1=True,
                steps=[8, 16, 32, 64, 100, 300],
                offsets=[0.5, 0.5, 0.5, 0.5, 0.5, 0.5],
                clip_boxes=False,
                variances=[0.1, 0.1, 0.2, 0.2],
                normalize_coords=True,
                subtract_mean=[123, 117, 104],
                swap_channels=[2, 1, 0],
                confidence_thresh=0.01,
                iou_threshold=0.45,
                top_k=200,
                nms_max_output_size=400)

# 2: Load the trained weights into the model.

weights_path = '01_09_weights.h5'

model.load_weights(weights_path, by_name=True)

# 3: Compile the model so that Keras won't complain the next time you load it.

adam = Adam(lr=0.001, beta_1=0.9, beta_2=0.999, epsilon=1e-08, decay=0.0)

ssd_loss = SSDLoss(neg_pos_ratio=3, alpha=1.0)

model.compile(optimizer=adam, loss=ssd_loss.compute_loss)

# %% [markdown]
# ## 2. Create a data generator for the evaluation dataset
#
# Instantiate a `DataGenerator` that will serve the evaluation dataset during the prediction phase.

# %%
dataset = DataGenerator(load_images_into_memory=True)

classes = np.arange(43)

images_dir = '/home/jet/data/'

# Ground truth
val_labels_filename   = '/home/jet/data/val_labels.csv'

dataset.parse_csv(images_dir=images_dir,
                        labels_filename=val_labels_filename,
                        input_format=['image_name', 'xmin',  'ymin', 'xmax','ymax', 'class_id'], # This is the order of the first six columns in the CSV file that contains the labels for your dataset. If your labels are in XML format, maybe the XML parser will be helpful, check the documentation.
                        include_classes='all')
# Out:
# Loading images into memory: 100%|██████████| 384/384 [00:01<00:00, 219.21it/s]

# %% [markdown]
# ## 3. Run the evaluation
# It runs predictions over the entire given dataset, then it matches these predictions to the ground truth boxes, then it computes the precision-recall curves for each class, then it samples 11 equidistant points from these precision-recall curves to compute the average precision for each class, and finally it computes the mean average precision over all classes.
# To be considered a correct detection, the area of overlap $a_o$ between the predicted bounding box $B_p$ and ground truth bounding box $B_{gt}$ must exceed $50\%$ (IOU metric)

# %%
evaluator = Evaluator(model=model,
                      n_classes=n_classes,
                      data_generator=dataset,
                      model_mode=model_mode)

results = evaluator(img_height=img_height,
                    img_width=img_width,
                    batch_size=1,
                    data_generator_mode='resize',
                    round_confidences=False,
                    matching_iou_threshold=0.5,
                    border_pixels='include',
                    sorting_algorithm='quicksort',
                    average_precision_mode='sample',
                    num_recall_points=11,
                    ignore_neutral_boxes=True,
                    return_precisions=True,
                    return_recalls=True,
                    return_average_precisions=True,
                    verbose=True)

mean_average_precision, average_precisions, precisions, recalls = results
# Out:
# Number of images in the evaluation dataset: 384
#
# Producing predictions batch-wise: 100%|██████████| 384/384 [00:16<00:00, 23.61it/s]
# Matching predictions to ground truth, class 1/42.: 100%|██████████| 995/995 [00:00<00:00, 25911.02it/s]
# Matching predictions to ground truth, class 2/42.: 100%|██████████| 459/459 [00:00<00:00, 26346.06it/s]
# Matching predictions to ground truth, class 3/42.: 100%|██████████| 102/102 [00:00<00:00, 24815.49it/s]
# Matching predictions to ground truth, class 4/42.: 100%|██████████| 413/413 [00:00<00:00, 29509.17it/s]
# Matching predictions to ground truth, class 5/42.: 100%|██████████| 124/124 [00:00<00:00, 23092.70it/s]
# Matching predictions to ground truth, class 6/42.: 100%|██████████| 613/613 [00:00<00:00, 35922.88it/s]
# Matching predictions to ground truth, class 7/42.: 100%|██████████| 1321/1321 [00:00<00:00, 40138.19it/s]
# Matching predictions to ground truth, class 8/42.: 100%|██████████| 464/464 [00:00<00:00, 24555.95it/s]
# Matching predictions to ground truth, class 9/42.: 100%|██████████| 337/337 [00:00<00:00, 28842.42it/s]
# Matching predictions to ground truth, class 10/42.: 100%|██████████| 1577/1577 [00:00<00:00, 24517.27it/s]
# Matching predictions to ground truth, class 11/42.: 100%|██████████| 187/187 [00:00<00:00, 31900.39it/s]
# Matching predictions to ground truth, class 12/42.: 100%|██████████| 41271/41271 [00:01<00:00, 39155.67it/s]
# Matching predictions to ground truth, class 13/42.: 100%|██████████| 12198/12198 [00:00<00:00, 42177.51it/s]
# Matching predictions to ground truth, class 14/42.: 100%|██████████| 156/156 [00:00<00:00, 26026.71it/s]
# Matching predictions to ground truth, class 15/42.: 100%|██████████| 35/35 [00:00<00:00, 13645.72it/s]
# Matching predictions to ground truth, class 16/42.: 100%|██████████| 17/17 [00:00<00:00, 10621.65it/s]
# Matching predictions to ground truth, class 17/42.: 100%|██████████| 508/508 [00:00<00:00, 31729.13it/s]
# Matching predictions to ground truth, class 18/42.: 100%|██████████| 273/273 [00:00<00:00, 23752.67it/s]
# Matching predictions to ground truth, class 19/42.: 100%|██████████| 8/8 [00:00<00:00, 6804.79it/s]
# Matching predictions to ground truth, class 20/42.: 100%|██████████| 44/44 [00:00<00:00, 17346.50it/s]
# Matching predictions to ground truth, class 21/42.: 100%|██████████| 48/48 [00:00<00:00, 24041.87it/s]
# Matching predictions to ground truth, class 22/42.: 100%|██████████| 20/20 [00:00<00:00, 9967.45it/s]
# Matching predictions to ground truth, class 23/42.: 100%|██████████| 67/67 [00:00<00:00, 20362.17it/s]
# Matching predictions to ground truth, class 24/42.: 100%|██████████| 8/8 [00:00<00:00, 6228.78it/s]
# Matching predictions to ground truth, class 25/42.: 100%|██████████| 63/63 [00:00<00:00, 19325.76it/s]
# Matching predictions to ground truth, class 26/42.: 100%|██████████| 35/35 [00:00<00:00, 13388.11it/s]
# Matching predictions to ground truth, class 27/42.: 100%|██████████| 7/7 [00:00<00:00, 5809.29it/s]
# Matching predictions to ground truth, class 28/42.: 100%|██████████| 5823/5823 [00:00<00:00, 52844.44it/s]
# Matching predictions to ground truth, class 29/42.: 100%|██████████| 19/19 [00:00<00:00, 11958.55it/s]
# Matching predictions to ground truth, class 30/42.: 100%|██████████| 23/23 [00:00<00:00, 10828.26it/s]
# Matching predictions to ground truth, class 31/42.: 100%|██████████| 8/8 [00:00<00:00, 6322.67it/s]
# Matching predictions to ground truth, class 32/42.: 100%|██████████| 115/115 [00:00<00:00, 27016.07it/s]
# Matching predictions to ground truth, class 33/42.: 100%|██████████| 97/97 [00:00<00:00, 25991.66it/s]
# Matching predictions to ground truth, class 34/42.: 100%|██████████| 44/44 [00:00<00:00, 13339.31it/s]
# Matching predictions to ground truth, class 35/42.: 100%|██████████| 134/134 [00:00<00:00, 20995.81it/s]
# Matching predictions to ground truth, class 36/42.: 100%|██████████| 170/170 [00:00<00:00, 29450.73it/s]
# Matching predictions to ground truth, class 37/42.: 100%|██████████| 5/5 [00:00<00:00, 4154.42it/s]
# Matching predictions to ground truth, class 38/42.: 100%|██████████| 8733/8733 [00:00<00:00, 35341.85it/s]
# Matching predictions to ground truth, class 39/42.: 100%|██████████| 10/10 [00:00<00:00, 8188.80it/s]
# Matching predictions to ground truth, class 40/42.: 100%|██████████| 79/79 [00:00<00:00, 23950.13it/s]
# Matching predictions to ground truth, class 41/42.: 100%|██████████| 47/47 [00:00<00:00, 25512.14it/s]
# Matching predictions to ground truth, class 42/42.: 100%|██████████| 143/143 [00:00<00:00, 32757.26it/s]
# Computing precisions and recalls, class 1/42
# Computing precisions and recalls, class 2/42
# Computing precisions and recalls, class 3/42
# Computing precisions and recalls, class 4/42
# Computing precisions and recalls, class 5/42
# Computing precisions and recalls, class 6/42
# Computing precisions and recalls, class 7/42
# Computing precisions and recalls, class 8/42
# Computing precisions and recalls, class 9/42
# Computing precisions and recalls, class 10/42
# Computing precisions and recalls, class 11/42
# Computing precisions and recalls, class 12/42
# Computing precisions and recalls, class 13/42
# Computing precisions and recalls, class 14/42
# Computing precisions and recalls, class 15/42
# Computing precisions and recalls, class 16/42
# Computing precisions and recalls, class 17/42
# Computing precisions and recalls, class 18/42
# Computing precisions and recalls, class 19/42
# Computing precisions and recalls, class 20/42
# Computing precisions and recalls, class 21/42
# Computing precisions and recalls, class 22/42
# Computing precisions and recalls, class 23/42
# Computing precisions and recalls, class 24/42
# Computing precisions and recalls, class 25/42
# Computing precisions and recalls, class 26/42
# Computing precisions and recalls, class 27/42
# Computing precisions and recalls, class 28/42
# Computing precisions and recalls, class 29/42
# Computing precisions and recalls, class 30/42
# Computing precisions and recalls, class 31/42
# Computing precisions and recalls, class 32/42
# Computing precisions and recalls, class 33/42
# Computing precisions and recalls, class 34/42
# Computing precisions and recalls, class 35/42
# Computing precisions and recalls, class 36/42
# Computing precisions and recalls, class 37/42
# Computing precisions and recalls, class 38/42
# Computing precisions and recalls, class 39/42
# Computing precisions and recalls, class 40/42
# Computing precisions and recalls, class 41/42
# Computing precisions and recalls, class 42/42
# Computing average precision, class 1/42
# Computing average precision, class 2/42
# Computing average precision, class 3/42
# Computing average precision, class 4/42
# Computing average precision, class 5/42
# Computing average precision, class 6/42
# Computing average precision, class 7/42
# Computing average precision, class 8/42
# Computing average precision, class 9/42
# Computing average precision, class 10/42
# Computing average precision, class 11/42
# Computing average precision, class 12/42
# Computing average precision, class 13/42
# Computing average precision, class 14/42
# Computing average precision, class 15/42
# Computing average precision, class 16/42
# Computing average precision, class 17/42
# Computing average precision, class 18/42
# Computing average precision, class 19/42
# Computing average precision, class 20/42
# Computing average precision, class 21/42
# Computing average precision, class 22/42
# Computing average precision, class 23/42
# Computing average precision, class 24/42
# Computing average precision, class 25/42
# Computing average precision, class 26/42
# Computing average precision, class 27/42
# Computing average precision, class 28/42
# Computing average precision, class 29/42
# Computing average precision, class 30/42
# Computing average precision, class 31/42
# Computing average precision, class 32/42
# Computing average precision, class 33/42
# Computing average precision, class 34/42
# Computing average precision, class 35/42
# Computing average precision, class 36/42
# Computing average precision, class 37/42
# Computing average precision, class 38/42
# Computing average precision, class 39/42
# Computing average precision, class 40/42
# Computing average precision, class 41/42
# Computing average precision, class 42/42

# %% [markdown]
# ## 4. Visualize the results
#
# Let's take a look:

# %%
for i in range(1, len(average_precisions)):
    print("{:<14}{:<6}{}".format(classes[i], 'AP', round(average_precisions[i], 3)))
print()
print("{:<14}{:<6}{}".format('','mAP', round(mean_average_precision, 3)))
# Out:
# 1             AP    0.683
# 2             AP    0.693
# 3             AP    0.666
# 4             AP    0.626
# 5             AP    0.705
# 6             AP    0.729
# 7             AP    0.805
# 8             AP    0.57
# 9             AP    0.671
# 10            AP    0.63
# 11            AP    1.0
# 12            AP    0.753
# 13            AP    0.69
# 14            AP    0.789
# 15            AP    0.803
# 16            AP    0.545
# 17            AP    0.632
# 18            AP    0.765
# 19            AP    1.0
# 20            AP    0.432
# 21            AP    0.5
# 22            AP    0.625
# 23            AP    0.711
# 24            AP    0.273
# 25            AP    0.86
# 26            AP    0.677
# 27            AP    1.0
# 28            AP    0.711
# 29            AP    0.599
# 30            AP    0.924
# 31            AP    1.0
# 32            AP    0.764
# 33            AP    1.0
# 34            AP    0.677
# 35            AP    0.524
# 36            AP    0.545
# 37            AP    0.0
# 38            AP    0.617
# 39            AP    0.545
# 40            AP    0.735
# 41            AP    0.545
# 42            AP    0.636
#
#               mAP   0.682

# %%
m = max((n_classes + 1) // 2, 2)
n = 2

fig, cells = plt.subplots(m, n, figsize=(n*8,m*8))
for i in range(m):
    for j in range(n):
        if n*i+j+1 > n_classes: break
        cells[i, j].plot(recalls[n*i+j+1], precisions[n*i+j+1], color='blue', linewidth=1.0)
        cells[i, j].set_xlabel('recall', fontsize=14)
        cells[i, j].set_ylabel('precision', fontsize=14)
        cells[i, j].grid(True)
        cells[i, j].set_xticks(np.linspace(0,1,11))
        cells[i, j].set_yticks(np.linspace(0,1,11))
        cells[i, j].set_title("{}, AP: {:.3f}".format(classes[n*i+j+1], average_precisions[n*i+j+1]), fontsize=16)
